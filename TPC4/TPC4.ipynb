# %%
import random

def criarLista1 (N):
    return [random.randint(1,100) for x in range(N)]

def criarLista2 (N):
    return [int(input("Selecione números inteiros")) for x in range(N)]

def somaLista (lista):
    soma= 0
    for n in lista :
        soma+= n
    return soma
def mediaLista (lista):
    soma= 0
    for n in lista:
        soma= soma+n
        x= soma/len(lista)
    return x
def Maior (lista):
    res= lista[0]
    for i in lista:
        if i > res:
            res= i
    return res
def Menor (lista):
    res=lista[0]
    for i in lista:
        if i < res:
            res= i
    return res
def Crescente(lista):
    for i in range(len(lista) - 1):
        if lista[i] > lista[i + 1]:
            return False
    return True
def Decrescente(lista):
    for i in range(len(lista) - 1):
        if lista[i] < lista[i + 1]:
            return False
    return True
def Encontrar(lista, x):
    for i, n in enumerate(lista):
        if n == x:
            return i
    return -1

def aplicacao (N):
    st1= input("Selecione a funcionalidade '1','2'")
    st2=input("Selecione o que fazer com a lista criada '0','3','4','5','6','7','8','9'")
    listainicial= []
    if st1 == "1" :
        listainicial = criarLista1(N)
        if st2 =="3":
            Y=somaLista(listainicial)
        if st2 =="4":
            Y=mediaLista(listainicial)
        if st2 =="5":
            Y=Maior(listainicial)
        if st2 =="6":
            Y=Menor(listainicial)
        if st2 =="7":
            Y=Crescente(listainicial)
        if st2 =="8":
            Y=Decrescente(listainicial)
        if st2 =="9":
            Y=Encontrar(listainicial,x)
        if st2 =="0":
            Y=print("Obrigado por ter usado a aplicação")
    if st1 == "2" :
        listainicial = criarLista2(N)
        if st2 =="3":
            Y=somaLista(listainicial)
        if st2 =="4":
            Y=mediaLista(listainicial)
        if st2 =="5":
            Y=Maior(listainicial)
        if st2 =="6":
            Y=Menor(listainicial)
        if st2 =="7":
            Y=Crescente(listainicial)
        if st2 =="8":
            Y=Decrescente(listainicial)
        if st2 =="9":
            x= int(input("Número que deseja procurar"))
            Y=Encontrar(listainicial,x)
        if st2 =="0":
            Y=print("Obrigado por ter usado a aplicação")
    
    return Y
aplicacao(10)
# Out:
# 9
